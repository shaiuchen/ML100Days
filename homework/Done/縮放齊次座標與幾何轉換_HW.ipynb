# %% [markdown]
# # Day 4 作業
#
# ## [作業目標]
# * 透過以下的插值演算法來放大與縮小 Lena 圖(放大與縮小4倍)，並比較各個演算法的時間差異：
#
#     1. Inter nearest interpolation
#     2. Inter linear interpolation
#     3. Inter area interpolation
#     4. Inter cubic interpolation
#     5. Inter lanczos4 interpolation
#
# ## [作業重點]
# * 熟悉 OpenCV 的 resize 函數
# * 學會使用 time 模組來計算程式運行時間
# * 觀察圖片的變化

# %%
import cv2
import numpy as np
import time
import matplotlib.pyplot as plt

# cv2 預設 color space 是 BGR，但 matplotlib，
# 顯示是以 RGB 來顯示，故需要做順序的調整

img_path = 'lena.png'
img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %% [markdown]
# # 進行放大的比較

# %%
# 方便顯示與進行縮放
interpolation_lst = [cv2.INTER_NEAREST, cv2.INTER_LINEAR, cv2.INTER_AREA, cv2.INTER_CUBIC, cv2.INTER_LANCZOS4]
interpolation_name = ['INTER_LANCZOS4', 'INTER_LINEAR', 'INTER_AREA', 'INTER_CUBIC', 'INTER_LANCZOS4']

# 定義欲放大與縮小的尺寸
small_length, big_length = int(img.shape[0] / 4), int(4 * img.shape[0])

# 定義作圖版面大小
plt.figure(figsize = (30, 6))


# 開始進行5種插值法的放大比較
for i in range(len(interpolation_lst)):
    start = time.time() # 按下碼表計時
    img_area_scale = cv2.resize(img, (big_length, big_length), interpolation=interpolation_lst[i])
    end = time.time() # 結束計時
    costtime = end - start
    
    # 開始做圖
    plt.subplot(1,5,i+1)
    plt.imshow(img_area_scale)
    plt.title(interpolation_name[i])

    print('{} zoom cost {}'.format(interpolation_name[i], costtime))

plt.show()
# Out:
# INTER_LANCZOS4 zoom cost 0.005699872970581055
# INTER_LINEAR zoom cost 0.0056629180908203125
# INTER_AREA zoom cost 0.0055310726165771484
# INTER_CUBIC zoom cost 0.013701915740966797
# INTER_LANCZOS4 zoom cost 0.050283193588256836

# %% [markdown]
# # 進行縮小的比較

# %%
plt.figure(figsize = (25, 5))

# 開始進行5種插值法的縮小比較
for i in range(len(interpolation_lst)):
    start = time.time() # 按下碼表計時
    img_area_scale = cv2.resize(img, (small_length, small_length), interpolation=interpolation_lst[i])
    end = time.time() # 結束計時
    costtime = end - start
    
    # 開始做圖
    plt.subplot(1,5,i+1)
    plt.imshow(img_area_scale)
    plt.title(interpolation_name[i])

    print('{} zoom cost {}'.format(interpolation_name[i], costtime))


plt.show()
# Out:
# INTER_LANCZOS4 zoom cost 0.0021810531616210938
# INTER_LINEAR zoom cost 0.0015861988067626953
# INTER_AREA zoom cost 0.006557941436767578
# INTER_CUBIC zoom cost 0.0005211830139160156
# INTER_LANCZOS4 zoom cost 0.001706838607788086
